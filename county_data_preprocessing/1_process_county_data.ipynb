# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### This script processes county data
# #### this script needs files: zip_codes_states.csv, Land_Area.csv, PEP_2017_PEPANNRES_with_ann.csv

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
def rchop(string, ending):
    """
    This function removes a specific substring from a given string
    string: a given string
    ending: the target substring to remove
    
    output: 
    string: updated string
    """
    if string.endswith(ending):
        return string[:-len(ending)]
    return string

# %% [markdown]
# #### process county location data

# %%
df = pd.read_csv('zip_codes_states.csv')
CA = df[df['state']=='CA']
loc = CA.drop('zip_code', axis=1).groupby('county').mean().add_prefix('mean_').reset_index()

# %% [markdown]
# #### process county area data

# %%
area_raw = pd.read_csv('Land_Area.csv')
area_1 = area_raw.drop(area_raw.index[[0,1]])
area_1['Areaname'] = area_1['Areaname'].map(lambda x: x[:-4])
area_2 = area_1.drop('STCOU', axis=1)
area_3 = area_2.rename(columns ={'Areaname': 'county'}, inplace=False)

# %% [markdown]
# #### process county population data

# %%
popu_raw = pd.read_csv('PEP_2017_PEPANNRES_with_ann.csv')
popu_2 = popu_raw.drop(popu_raw.index[0])
popu_3 = popu_2.drop(['GEO.id', 'GEO.id2', 'rescen42010', 'resbase42010'], axis=1)

popu8years = popu_3.loc[: , "respop72010":"respop72017"]
popu8years = popu8years.apply(pd.to_numeric)
popu_3['popu_mean'] = popu8years.mean(axis=1)

popu_4 = popu_3[['GEO.display-label', 'popu_mean']]
popu_5 = popu_4.rename(columns ={'GEO.display-label': 'county'}, inplace=False)
popu_5['county'] = popu_5['county'].map(lambda x: rchop(x, ' County, California'))

# %% [markdown]
# #### merge all kinds of county data to one file

# %%
loc_and_area = pd.merge(loc, area_3, on='county')
county = pd.merge(loc_and_area, popu_5, on='county')
county['popu_density'] = county['popu_mean']/county['Land Area (mi^2)']

# %%
county.to_csv('county_data.csv')

# %%
county
# Out:
#              county  mean_latitude  mean_longitude  Land Area (mi^2)  \
# 0           Alameda          37.73         -122.10            821.26
# 1            Alpine          38.67         -120.06            743.23
# 2            Amador          38.45         -120.71            604.26
# 3             Butte          39.64         -121.60           1677.22
# 4         Calaveras          38.21         -120.56           1036.92
# 5            Colusa          39.19         -122.17           1156.32
# 6      Contra Costa          37.90         -122.01            802.18
# 7         Del Norte          41.82         -124.06           1229.84
# 8         El Dorado          38.81         -120.50           1791.29
# 9            Fresno          36.74         -119.70           6017.89
# 10            Glenn          39.60         -122.20           1327.25
# 11         Humboldt          40.61         -123.94           4052.52
# 12         Imperial          32.99         -115.41           4482.08
# 13             Inyo          36.58         -117.58          10227.75
# 14             Kern          35.35         -118.65           8162.03
# 15            Kings          36.15         -119.85           1391.58
# 16             Lake          39.04         -122.77           1329.59
# 17           Lassen          40.53         -120.57           4720.61
# 18      Los Angeles          33.80         -118.28           4752.32
# 19           Madera          37.19         -119.80           2153.39
# 20            Marin          38.04         -122.67            828.22
# 21         Mariposa          37.57         -119.96           1462.89
# 22        Mendocino          39.33         -123.49           3878.50
# 23           Merced          37.29         -120.63           1972.02
# 24            Modoc          41.46         -120.66           4203.62
# 25             Mono          38.03         -119.12           3131.89
# 26         Monterey          36.45         -121.47           3771.11
# 27             Napa          38.49         -122.40            788.34
# 28           Nevada          39.28         -120.74            974.54
# 29           Orange          33.63         -117.76            947.91
# 30           Placer          39.02         -120.85           1500.24
# 31           Plumas          39.96         -120.84           2613.75
# 32        Riverside          33.74         -116.20           7303.81
# 33       Sacramento          38.44         -121.43            995.65
# 34       San Benito          36.77         -121.33           1390.81
# 35   San Bernardino          34.61         -116.13          20106.39
# 36        San Diego          32.93         -116.95           4525.92
# 37    San Francisco          37.78         -122.61            231.89
# 38      San Joaquin          37.95         -121.25           1426.37
# 39  San Luis Obispo          35.40         -120.60           3615.73
# 40        San Mateo          37.45         -122.34            741.07
# 41    Santa Barbara          34.52         -119.99           3789.56
# 42      Santa Clara          37.21         -121.72           1304.53
# 43       Santa Cruz          37.04         -122.01            607.72
# 44           Shasta          40.72         -122.14           3847.61
# 45           Sierra          39.56         -120.61            962.03
# 46         Siskiyou          41.61         -122.65           6347.81
# 47           Solano          38.23         -122.01            906.85
# 48           Sonoma          38.45         -122.88           1768.35
# 49       Stanislaus          37.60         -120.94           1514.80
# 50           Sutter          39.01         -121.67            608.86
# 51           Tehama          40.13         -122.08           2962.30
# 52          Trinity          40.66         -123.07           3207.79
# 53           Tulare          36.23         -119.10           4839.41
# 54         Tuolumne          37.98         -120.21           2274.52
# 55          Ventura          34.16         -119.08           2208.36
# 56             Yolo          38.70         -121.91           1022.87
# 57             Yuba          39.32         -121.29            643.55
#
#      popu_mean  popu_density
# 0   1593792.50       1940.67
# 1      1105.00          1.49
# 2     37383.00         61.87
# 3    223370.38        133.18
# 4     45092.75         43.49
# 5     21445.50         18.55
# 6   1102058.25       1373.83
# 7     27803.12         22.61
# 8    183484.88        102.43
# 9    959688.50        159.47
# 10    27982.62         21.08
# 11   135288.00         33.38
# 12   178495.00         39.82
# 13    18282.75          1.79
# 14   867355.12        106.27
# 15   150827.00        108.39
# 16    64186.75         48.28
# 17    32507.25          6.89
# 18 10024406.50       2109.37
# 19   153376.75         71.23
# 20   258611.75        312.25
# 21    17829.88         12.19
# 22    87503.25         22.56
# 23   264342.00        134.05
# 24     9207.50          2.19
# 25    14134.12          4.51
# 26   428696.62        113.68
# 27   139825.00        177.37
# 28    98733.25        101.31
# 29  3116880.62       3288.16
# 30   367746.75        245.13
# 31    19078.38          7.30
# 32  2309713.38        316.23
# 33  1472467.88       1478.90
# 34    57702.50         41.49
# 35  2098289.38        104.36
# 36  3230210.50        713.71
# 37   846723.00       3651.40
# 38   713010.38        499.88
# 39   276992.88         76.61
# 40   750852.00       1013.20
# 41   437025.50        115.32
# 42  1874793.88       1437.14
# 43   270178.62        444.58
# 44   178423.88         46.37
# 45     3044.38          3.16
# 46    43910.38          6.92
# 47   428237.38        472.23
# 48   496013.12        280.49
# 49   529130.75        349.31
# 50    95197.62        156.35
# 51    63298.12         21.37
# 52    13261.50          4.13
# 53   454405.12         93.90
# 54    54218.88         23.84
# 55   841324.88        380.97
# 56   208887.38        204.22
# 57    73864.00        114.78
